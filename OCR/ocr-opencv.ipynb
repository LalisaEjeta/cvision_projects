# %% [markdown]
# # Connect to tesseract

# %% [markdown]
# Download tesseract software from [link](https://github.com/UB-Mannheim/tesseract/wiki?utm_source=chatgpt.com)

# %%
import pytesseract

pytesseract.pytesseract.tesseract_cmd = (
    r"C:\Program Files\Tesseract-OCR\tesseract.exe"
)

text = pytesseract.image_to_string(gray)

print(text)

# %% [markdown]
# # First image

# %%
import cv2
import pytesseract

img = cv2.imread("text-image.png")

gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# upscale
gray = cv2.resize(
    gray,
    None,
    fx=2,
    fy=2,
    interpolation=cv2.INTER_CUBIC
)

# adaptive threshold
gray = cv2.adaptiveThreshold(
    gray,
    255,
    cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    cv2.THRESH_BINARY,
    11,
    2
)

text = pytesseract.image_to_string(
    gray,
    config="--psm 6"
)

print(repr(text))
# Out:
# '4 eo S) EE. © O <<\nSa er\n. S So\n\\ \\ Coe\no 0883 ee\n\\ A |\n‘ gn &\n\\\n\\ oe\n\\X SEE\nWN Se .\nFoe S08 - \\\nXY\n\\\n'

# %% [markdown]
# # Second image

# %%
import cv2
import pytesseract

img = cv2.imread("text-images.jpeg")

text = pytesseract.image_to_string(
    img,
    config="--psm 6"
)

print(repr(text))
# Out:
# 'It was the best of\ntimes, it was the worst\nof times, it was the age\nof wisdom, it was the\nage of foolishness...\n'
